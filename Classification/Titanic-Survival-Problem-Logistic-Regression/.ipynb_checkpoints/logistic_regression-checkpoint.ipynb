# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns

# %%
train = pd.read_csv("titanic_train.csv")
test = pd.read_csv("titanic_test.csv")

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
sns.heatmap(train.isnull())
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x = "Survived" , hue = "Sex" , data = train)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.distplot(train["Age"])
# Out:
# /home/huda/.local/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.countplot(x = "SibSp" , data = train)
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='count'>

# %%
train["Fare"].hist()
# Out:
# <AxesSubplot:>

# %%
def fill_age(cols):
    Age = cols[0]
    Pclass = cols[1]
    if pd.isnull(Age):
        if Pclass == 1:
            return 37
        elif Pclass == 2:
            return 29
        else:
            return 34
    else:
        return Age

# %%
train["Age"] = train[["Age" , "Pclass"]].apply(fill_age , axis = 1)

# %%
sns.heatmap(train.isnull())
# Out:
# <AxesSubplot:>

# %%
train.drop("Cabin" , axis = 1 , inplace=True)

# %%
sns.heatmap(train.isnull())
# Out:
# <AxesSubplot:>

# %%
train.dropna(inplace=True)

# %%
sns.heatmap(train.isnull())
# Out:
# <AxesSubplot:>

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
sex = pd.get_dummies(train["Sex"] , drop_first=True)

# %%
embark = pd.get_dummies(train["Embarked"] , drop_first=True)

# %%
train = pd.concat([train , sex , embark ], axis = 1)

# %%
train.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Embarked  male  Q  S
# 0      0  A/5 21171   7.2500        S     1  0  1
# 1      0   PC 17599  71.2833        C     0  0  0

# %%
train.drop(["Sex" , "Embarked" , "Ticket" , "Name"] , axis=1, inplace = True)

# %%
train.head(2)
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  male  Q  S
# 0            1         0       3  22.0      1      0   7.2500     1  0  1
# 1            2         1       1  38.0      1      0  71.2833     0  0  0

# %%
train.drop( "PassengerId" , axis=1, inplace = True)

# %%
train.head(2)
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  male  Q  S
# 0         0       3  22.0      1      0   7.2500     1  0  1
# 1         1       1  38.0      1      0  71.2833     0  0  0

# %%
pclass = pd.get_dummies(train["Pclass"] , drop_first=True)

# %%
train = pd.concat([train , pclass ], axis = 1)

# %%
train.drop("Pclass" , axis = 1 , inplace=True)

# %%
train.head(2)
# Out:
#    Survived   Age  SibSp  Parch     Fare  male  Q  S  2  3
# 0         0  22.0      1      0   7.2500     1  0  1  0  1
# 1         1  38.0      1      0  71.2833     0  0  0  0  0

# %%
train.columns = ["Survived" , "Age" , "SibSp" , "Parch" , "Fare" , "Male" , "Qemb" , "Semb" , "class2" , "class3"]

# %%
train.head(2)
# Out:
#    Survived   Age  SibSp  Parch     Fare  Male  Qemb  Semb  class2  class3
# 0         0  22.0      1      0   7.2500     1     0     1       0       1
# 1         1  38.0      1      0  71.2833     0     0     0       0       0

# %% [markdown]
# # DATA PRE-PROCESSING

# %%
X = train.iloc[:,1:].values
y = train.iloc[:,0].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , X_test , y_train , y_test = train_test_split(X , y , train_size=0.7 , random_state=101)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %% [markdown]
# # MODEL TRAINING

# %%
from sklearn.linear_model import LogisticRegression

# %%
classifier = LogisticRegression()

# %%
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# # EVALUATIONS ON TEST DATA

# %%
predictions = classifier.predict(X_test)

# %%
from sklearn.metrics import classification_report , confusion_matrix , accuracy_score

# %%
cm = confusion_matrix(y_test , predictions)

# %%
cm
# Out:
# array([[148,  15],
#        [ 33,  71]])

# %%
acc_score = accuracy_score(y_test , predictions)

# %%
acc_score
# Out:
# 0.8202247191011236

# %%
print(classification_report(y_test , predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.91      0.86       163
#            1       0.83      0.68      0.75       104
#
#     accuracy                           0.82       267
#    macro avg       0.82      0.80      0.80       267
# weighted avg       0.82      0.82      0.82       267
