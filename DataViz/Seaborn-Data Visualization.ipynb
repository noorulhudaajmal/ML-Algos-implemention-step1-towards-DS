# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import math
import pandas as pd

# %%
# %matplotlib inline

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.displot(tips["tip"])

# %%
sns.histplot(tips["tip"],kde=True)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
sns.histplot(tips["tip"],bins=55)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %% [markdown]
# # LMPLOT:

# %%
df = sns.load_dataset("anscombe")
sns.lmplot(x="x",y="y",data=df)

# %%
df.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
sns.lmplot(x="size",y="tip",data=tips)

# %% [markdown]
# # SCATTER PLOT:

# %%
sns.scatterplot(x="tip",y="total_bill",data=tips,hue="sex",size="size",lw=0)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %% [markdown]
# # LINEPLOT

# %%
sns.set_theme(style="darkgrid")
sns.lineplot(x="tip",y="size",data=tips,hue="sex")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='size'>

# %%
x=pd.Series([0,2*3.14,3*3.14,6*3.14,8*3.14,10*3.14])
y=x.apply(math.cos)
sns.lineplot(x=x,y=y)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # DISPLOT:  displot(data=,x=,row=,col=,)

# %%
sns.displot(tips,x="total_bill",row="sex",col="size",binwidth=2)

# %% [markdown]
# # JOINTPLOT:  jointplot(x=,y=,data=)

# %%
sns.jointplot(x=tips["total_bill"],y=tips["tip"],kind="kde",data=tips)
#plot_kinds = ["scatter", "hist", "hex", "kde", "reg", "resid"]

# %%
sns.jointplot(x=tips["total_bill"],y=tips["tip"],kind="hex",color="green")

# %% [markdown]
# # JOINTGRID

# %%
g=sns.JointGrid(data=tips,x="total_bill",y="tip",marginal_ticks=True)
# Set a log scaling on the y axis
g.ax_joint.set(yscale="log")

# Create an inset legend for the histogram colorbar
cax = g.figure.add_axes([.15, .55, .02, .2])

# Add the joint and marginal histogram plots
g.plot_joint(
    sns.histplot, discrete=(True, False),
    cmap="light:#03012d", pmax=.8, cbar=True, cbar_ax=cax
)
g.plot_marginals(sns.histplot, element="step", color="#03012d")

# %% [markdown]
# # PAIRPLOT:  pairplot(dataframe)

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips,hue="sex")

# %% [markdown]
# # RUGPLOT:  rugplot(series/df(col))

# %%
sns.rugplot(tips["tip"])
sns.rugplot(tips["total_bill"])
# Out:
# <AxesSubplot:xlabel='tip'>

# %% [markdown]
# # kde : kernel density estimate (sum of all the normal distribution of the rugplot)

# %%
sns.kdeplot(tips["size"])
# Out:
# <AxesSubplot:xlabel='size', ylabel='Density'>

# %%
sns.kdeplot(tips["tip"])
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %%
sns.kdeplot(tips["total_bill"])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# # DISPLOT:

# %%
sns.displot(x="tip",y="size",data=tips)

# %%
sns.displot(x="total_bill",data=tips,kde=True)

# %% [markdown]
# # CATEGORICAL PLOTS:

# %% [markdown]
# # BARLOT: (x=categorical col, y=numerical col, data= dataset/dataframe, estimator=func[default=mean()])

# %%
sns.barplot(x="size",y="tip",data=tips,estimator = np.std)
# Out:
# <AxesSubplot:xlabel='size', ylabel='tip'>

# %%
sns.barplot(x="size",y="total_bill",data=tips,estimator=np.var)
# Out:
# <AxesSubplot:xlabel='size', ylabel='total_bill'>

# %% [markdown]
# ## COUNTPLOT: countplot(col,data)

# %%
sns.countplot(x="size",data=tips)
# Out:
# <AxesSubplot:xlabel='size', ylabel='count'>

# %% [markdown]
# ## BOXPLOT : boxplot(x=cat,y=numerical,data)

# %%
sns.boxplot(x="sex",y="tip",data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(x="size",y="total_bill",data=tips,hue="smoker")
# Out:
# <AxesSubplot:xlabel='size', ylabel='total_bill'>

# %% [markdown]
# ## VIOLINPLOT: voilinplot(x=cat,y=num,data)

# %%
sns.violinplot(x="size",y="total_bill",data=tips,hue="smoker")
# Out:
# <AxesSubplot:xlabel='size', ylabel='total_bill'>

# %%
sns.violinplot(x="sex",y="tip",data=tips,split=True)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %% [markdown]
# ## STRIPPLOT:

# %%
sns.stripplot(x="size",y="tip",data=tips)
# Out:
# <AxesSubplot:xlabel='size', ylabel='tip'>

# %%
sns.stripplot(x="size",y="tip",data=tips,jitter=False)
# Out:
# <AxesSubplot:xlabel='size', ylabel='tip'>

# %%
sns.stripplot(x="size",y="tip",data=tips,dodge=True,hue="sex")
# Out:
# <AxesSubplot:xlabel='size', ylabel='tip'>

# %% [markdown]
# ## SWARMPLOT: combination of strip and violin plot

# %%
sns.swarmplot(x="sex",y="tip",data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
sns.violinplot(x="smoker",y="tip",data=tips,pallete="coolwarm")
sns.swarmplot(x="smoker",y="tip",data=tips,color="black")
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='tip'>

# %% [markdown]
# # CATPLOT:  (prev:factotplot)

# %%
sns.catplot(x="size",y="total_bill",data=tips,kind="bar")

# %%
sns.catplot(x="size",y="total_bill",data=tips,kind="box")

# %%
flights = sns.load_dataset("flights")

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %% [markdown]
# # MATRIX PLOTS:

# %% [markdown]
# ## heatmap:

# %%
mat=pd.DataFrame({0:[11,22,33],1:[13,53,33],2:[34,67,22]})

# %%
mat
# Out:
#     0   1   2
# 0  11  13  34
# 1  22  53  67
# 2  33  33  22

# %%
sns.heatmap(mat)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(mat,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(mat,annot=True,cmap="coolwarm")
# Out:
# <AxesSubplot:>

# %%
fp = flights.pivot_table(index="month",columns="year",values="passengers")

# %%
fp
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(fp)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.heatmap(fp,cmap="coolwarm",lw=2,linecolor="black")
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %% [markdown]
# ## clustermap:
# ### make clusters based on some similiarity

# %%
sns.clustermap(fp,annot=True,lw=4,cmap="coolwarm")

# %%
sns.clustermap(fp,annot=True,lw=4,cmap="coolwarm",standard_scale=1)

# %% [markdown]
# # GRIDS:

# %%
mp = sns.PairGrid(tips)
mp.map_diag(sns.violinplot)
mp.map_upper(sns.histplot)
mp.map_lower(sns.kdeplot)

# %% [markdown]
# # FACETGRID

# %%
m = sns.FacetGrid(data=tips,row="smoker",col="time")
m.map(sns.kdeplot,"tip")

# %% [markdown]
# # REGRESSION PLOTS

# %% [markdown]
# ## lmplot():  lmplot(x=,y=,data=)

# %%
sns.lmplot(x="total_bill",y="tip",data=tips,hue="smoker",markers=["o","+"])

# %%
sns.lmplot(x="total_bill",y="tip",data=tips,row="smoker",col="sex")

# %%
sns.lmplot(x="total_bill",y="tip",data=tips,col="day",hue="sex",aspect=0.6,height=5)

# %% [markdown]
# # STYLE & COLOR:

# %%
sns.set_style("whitegrid")
sns.countplot(x="size",data=tips)
#sns.despine(left=True,bottom=True)
# Out:
# <AxesSubplot:xlabel='size', ylabel='count'>

# %%
plt.figure(figsize=(12,2))
sns.countplot(x="size",data=tips)
# Out:
# <AxesSubplot:xlabel='size', ylabel='count'>

# %% [markdown]
# ## set_context("poster","notebook","paper",... , font_scale=)

# %%
sns.set_context("poster",font_scale=0.5)
sns.lmplot(x="tip",y="total_bill",data=tips,col="smoker")

# %% [markdown]
# ## color:

# %%
sns.displot(data=tips,kde=True,palette="coolwarm")
sns.set_context("paper",font_scale=1.5)

# %%
sns.set_context("paper",font_scale=1.5)
sns.lmplot(x="total_bill",y="tip",data=tips,hue="sex",palette="afmhot")

# %% [markdown]
# palette => matplotlib color map (google search)
