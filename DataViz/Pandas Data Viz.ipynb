# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df = pd.read_csv("Pandas-Built-in-Data-Viz/df1",index_col=0)
df2 = pd.read_csv("Pandas-Built-in-Data-Viz/df2")

# %%
df.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df["C"].hist(bins=30,lw=2)
# Out:
# <AxesSubplot:>

# %%
df["A"].plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
df["B"].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2.plot.area(alpha=0.1)
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df2.plot.line(x="a",y="b")
# Out:
# <AxesSubplot:xlabel='a'>

# %%
df.plot.scatter(x="A",y="D",cmap="coolwarm",c="B")
# Out:
# <AxesSubplot:xlabel='A', ylabel='D'>

# %%
df.plot.scatter(x="A",y="D",s=df["C"]*20)
# Out:
# <AxesSubplot:xlabel='A', ylabel='D'>

# %%
df.plot.box()
# Out:
# <AxesSubplot:>

# %%
df2.plot.box()
# Out:
# <AxesSubplot:>

# %%
dfm = pd.DataFrame(np.random.rand(1000,2),columns=["A","B"])

# %%
dfm.head()
# Out:
#           A         B
# 0  0.733642  0.282892
# 1  0.673076  0.687829
# 2  0.817431  0.215919
# 3  0.117019  0.900700
# 4  0.942372  0.415270

# %%
dfm.plot.hexbin(x="A",y="B",gridsize=20,cmap="coolwarm")
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
dfm["B"].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
dfm.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>
